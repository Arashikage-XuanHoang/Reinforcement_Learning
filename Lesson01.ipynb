# %%
import gymnasium as gym
import matplotlib.pyplot as plt

# %%
env = gym.make("MountainCar-v0")
env.reset()

done = False 

while not done: 
    action = 2 
    new_state, reward, done, _ = env.step(action)
    env.render()

env.close()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 8
#       6 while not done:
#       7     action = 2
# ----> 8     new_state, reward, done, _ = env.step(action)
#       9     env.render()
#      11 env.close()
#
# ValueError: too many values to unpack (expected 4)

# %%
# Generate random action 
random_action = env.action_space.sample()
print(random_action)


returnValue = env.step(random_action)
print(returnValue)

# (observation, reward, terminated, truncated, info)
# observation = state, vị trí hiện tại (0 - 15)
# reward : thưởng cho step này 
# terminated = 0 : đây không phải trạng thái cuối cùng
# truncated
# Out:
# 0
# (4, 0, False, False, {'prob': 0.33333333333333337})

# %%
plt.imshow(env.render())
plt.axis('off')
plt.show()

# %%
for i in range(30):
    randomAction = env.action_space()
    returnValue = env.step(randomAction)
    env.render()
    time.sleep(2)
    if returnValue[2]:
        break
env.close()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 for i in range(30):
# ----> 2     randomAction = env.action_space()
#       3     returnValue = env.step(randomAction)
#       4     env.render()
#
# TypeError: 'Discrete' object is not callable
